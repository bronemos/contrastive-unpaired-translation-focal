# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/MyDrive/BSc\ Thesis/contrastive-unpaired-translation
# Out:
# /content/gdrive/MyDrive/BSc Thesis/contrastive-unpaired-translation

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# ...

# %%
# %%bash
# conda install --channel defaults conda python=3.6 --yes
# conda update --channel defaults --all --yes
# Out:
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cryptography-3.4.7         |   py36hd23ed53_0         1.0 MB
#     libgomp-9.3.0              |      h5101ec6_17         378 KB
#     ld_impl_linux-64-2.35.1    |       h7274673_9         637 KB
#     pycparser-2.20             |             py_2          94 KB
#     brotlipy-0.7.0             |py36h27cfd23_1003         349 KB
#     conda-4.10.1               |   py36h06a4308_1         3.1 MB
#     ncurses-6.2                |       he6710b0_1         1.1 MB
#     tqdm-4.59.0                |     pyhd3eb1b0_1          90 KB
#     readline-8.1               |       h27cfd23_0         464 KB
#     libstdcxx-ng-9.3.0         |      hd4cf53a_17         4.0 MB
# ...

# %%
# !conda env create -f environment.yml
# Out:
# done
# done
#
# ...
# mkl-service-2.3.0    | 52 KB     | : 100% 1.0/1 [00:00<00:00,  9.07it/s]
# numpy-1.19.2         | 22 KB     | : 100% 1.0/1 [00:00<00:00, 16.51it/s]
# mkl_random-1.1.1     | 327 KB    | : 100% 1.0/1 [00:00<00:00, 11.62it/s]
# blas-1.0             | 6 KB      | : 100% 1.0/1 [00:00<00:00, 14.30it/s]
# libgfortran4-7.5.0   | 995 KB    | : 100% 1.0/1 [00:00<00:00,  9.66it/s]
# libgfortran-ng-7.5.0 | 22 KB     | : 100% 1.0/1 [00:00<00:00, 16.65it/s]
# mkl_fft-1.3.0        | 170 KB    | : 100% 1.0/1 [00:00<00:00, 16.14it/s]
# ninja-1.10.2         | 1.4 MB    | : 100% 1.0/1 [00:00<00:00,  5.10it/s]
# intel-openmp-2021.2. | 1.3 MB    | : 100% 1.0/1 [00:00<00:00,  9.19it/s]
# mkl-2020.2           | 138.3 MB  | : 100% 1.0/1 [00:05<00:00,  5.62s/it]
# scipy-1.5.2          | 14.4 MB   | : 100% 1.0/1 [00:00<00:00,  1.32it/s]
# cudatoolkit-10.1.243 | 347.4 MB  | : 100% 1.0/1 [00:17<00:00, 17.12s/it]
# pytorch-1.4.0        | 432.9 MB  | : 100% 1.0/1 [01:07<00:00, 67.66s/it]
# ...

# %%
# %%bash
# chmod 755 ./datasets/download_cut_dataset.sh
# bash ./datasets/download_cut_dataset.sh maps
# Out:
# Specified [maps]
# Archive:  ./datasets/maps.zip
#    creating: ./datasets/maps/trainA/
#   inflating: ./datasets/maps/trainA/850_A.jpg
#   inflating: ./datasets/maps/trainA/1054_A.jpg
#   inflating: ./datasets/maps/trainA/847_A.jpg
#   inflating: ./datasets/maps/trainA/1053_A.jpg
#   inflating: ./datasets/maps/trainA/893_A.jpg
#   inflating: ./datasets/maps/trainA/888_A.jpg
#   inflating: ./datasets/maps/trainA/584_A.jpg
#   inflating: ./datasets/maps/trainA/654_A.jpg
#   inflating: ./datasets/maps/trainA/727_A.jpg
#   inflating: ./datasets/maps/trainA/934_A.jpg
#   inflating: ./datasets/maps/trainA/972_A.jpg
#   inflating: ./datasets/maps/trainA/747_A.jpg
#   inflating: ./datasets/maps/trainA/598_A.jpg
#   inflating: ./datasets/maps/trainA/662_A.jpg
#   inflating: ./datasets/maps/trainA/110_A.jpg
#   inflating: ./datasets/maps/trainA/526_A.jpg
#   inflating: ./datasets/maps/trainA/848_A.jpg
#   inflating: ./datasets/maps/trainA/324_A.jpg
# ...

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla P100-PCIE-16GB (UUID: GPU-44c7101a-c672-950a-5c12-908cd40bb344)

# %%
# %%shell
# eval "$(conda shell.bash hook)" # copy conda command to shell
# conda activate contrastive-unpaired-translation
# python --version
# python train.py --dataroot ./datasets/maps --name maps_fast --CUT_mode FastCUT
# conda deactivate
# Out:
# Python 3.6.13 :: Anaconda, Inc.
# ----------------- Options ---------------
#                  CUT_mode: FastCUT                       	[default: CUT]
#                batch_size: 1
#                     beta1: 0.5
#                     beta2: 0.999
#           checkpoints_dir: ./checkpoints
#            continue_train: True                          	[default: False]
#                 crop_size: 256
#                  dataroot: ./datasets/maps               	[default: placeholder]
#              dataset_mode: unaligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: None
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                easy_label: experiment_name
#                     epoch: latest
#               epoch_count: 180                           	[default: 1]
#           evaluation_freq: 5000
# ...
